# %% [markdown]
# # Understanding Unicode

# %% [markdown]
# (a) What Unicode character does chr(0) return?

# %%
chr(0)
# Out:
# '\x00'

# %% [markdown]
# U+0000

# %% [markdown]
# (b) How does this character’s string representation (\_\_repr\_\_()) differ from its printed
# representation?

# %%
print(chr(0))

# %% [markdown]
# String representation is '\x00', however when this is printed; U+0000 has no visible glyph, so string looks like empty string.

# %% [markdown]
# (c) What happens when this character occurs in text?

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
print('\x00\x00\x00')

# %%
len('\x00\x00\x00')
# Out:
# 3

# %%
len(s)
# Out:
# 3

# %% [markdown]
# In general, whenever printed, the representation is not visible. However, it consumes data; for example string "\x00\x00\x00" has length 3, even if it's printed representation is empty.

# %% [markdown]
# ## Appendix: Random Unicode Experiments

# %%
"\x00".encode("utf-8")
# Out:
# b'\x00'

# %%
"\x00".encode("utf-16")
# Out:
# b'\xff\xfe\x00\x00'

# %%
"\x00".encode("utf-32")
# Out:
# b'\xff\xfe\x00\x00\x00\x00\x00\x00'

# %%
"\x00".encode("utf-16-le")  # b'\x00\x00'
# Out:
# b'\x00\x00'

# %%
"\x00".encode("utf-16-be")  # b'\x00\x00'
# Out:
# b'\x00\x00'

# %%
"\x00".encode("utf-32-le")  # b'\x00\x00\x00\x00'
# Out:
# b'\x00\x00\x00\x00'

# %%
"\x00".encode("utf-32-be")  # b'\x00\x00\x00\x00'
# Out:
# b'\x00\x00\x00\x00'

# %% [markdown]
# Any zero bytes
