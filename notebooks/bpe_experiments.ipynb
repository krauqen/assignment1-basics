# %%
from cs336_basics.bpe import BPE

# %%
bpe = BPE('/home/krauq/src/assignment1-basics/tests/fixtures/bpe_sennrich_example.txt', 256+1+6, ['<|endoftext|>'])

# %%
bpe.pretokenization_dict

# %%
bpe.merges
# Out:
# []

# %%
trained = bpe.train()

# %%
bpe.pretokenization_dict
# Out:
# defaultdict(int,
#             {(b'low',): 1,
#              (b' ', b'low'): 4,
#              (b'\n',): 2,
#              (b'low', b'e', b'r'): 1,
#              (b' ', b'low', b'e', b'r'): 1,
#              (b' ', b'w', b'i', b'd', b'est'): 3,
#              (b'ne', b'west'): 1,
#              (b' ', b'ne', b'west'): 5})

# %%
bpe.merges
# Out:
# [(b's', b't'),
#  (b'e', b'st'),
#  (b'o', b'w'),
#  (b'l', b'ow'),
#  (b'w', b'est'),
#  (b'n', b'e')]

# %%
bpe.vocab
# Out:
# {0: b'\x00',
#  1: b'\x01',
#  2: b'\x02',
#  3: b'\x03',
#  4: b'\x04',
#  5: b'\x05',
#  6: b'\x06',
#  7: b'\x07',
#  8: b'\x08',
#  9: b'\t',
#  10: b'\n',
#  11: b'\x0b',
#  12: b'\x0c',
#  13: b'\r',
#  14: b'\x0e',
#  15: b'\x0f',
#  16: b'\x10',
#  17: b'\x11',
#  18: b'\x12',
#  19: b'\x13',
#  20: b'\x14',
#  21: b'\x15',
#  22: b'\x16',
#  23: b'\x17',
#  24: b'\x18',
#  25: b'\x19',
#  26: b'\x1a',
#  27: b'\x1b',
#  28: b'\x1c',
#  29: b'\x1d',
#  30: b'\x1e',
#  31: b'\x1f',
#  32: b' ',
#  33: b'!',
#  34: b'"',
#  35: b'#',
#  36: b'$',
#  37: b'%',
#  38: b'&',
#  39: b"'",
#  40: b'(',
#  41: b')',
#  42: b'*',
#  43: b'+',
#  44: b',',
#  45: b'-',
#  46: b'.',
#  47: b'/',
#  48: b'0',
#  49: b'1',
#  50: b'2',
#  51: b'3',
#  52: b'4',
#  53: b'5',
#  54: b'6',
#  55: b'7',
#  56: b'8',
#  57: b'9',
#  58: b':',
#  59: b';',
#  60: b'<',
#  61: b'=',
#  62: b'>',
#  63: b'?',
#  64: b'@',
#  65: b'A',
#  66: b'B',
#  67: b'C',
#  68: b'D',
#  69: b'E',
# ...
